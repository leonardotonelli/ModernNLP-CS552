# %% [markdown]
# # 📚 Exercise Session - Week 1
#
# Welcome to Week 1 exercise session of **CS-552: Modern NLP**!
#
# > **What will be covered:**
# > 1. [**TASK A:** Training a word embedding model](#1)
# > 2. [**TASK B:** Word embedding similarity](#2)
# > 3. [**TASK C:** Sentiment analysis of movie reviews](#3)
#
# > **By the end of the session you will be able to:**
# > - ✅  train from scratch a word embedding model
# > - ✅  load and use pre-trained word embeddings
# > - ✅  perform word embedding analogies and understand their implicit biases
# > - ✅  train and evaluate a sentiment classifier using word embeddings

# %% [markdown]
# ## Intro - Word embedding models
#
# #### 🔵 What?
# A word embedding is a learned representation for text where words that have the same meaning have a similar representation. It is this approach to representing words and documents that may be considered one of the key breakthroughs of deep learning on challenging natural language processing problems.
#
#
# #### 🟡 How?
# There are different versions of word embeddings depending on the way the embeddings are learned.
# - Some of the models learn a focus word given the neighboring words that surround them
# - Some other models learn the neighboring words given the focus word.
# - Some other word embedding models try to derive the relationship between the words from global statistics of the words in the overall corpus.
#
#
# #### 🟣 Why?
# Word embedding in NLP is an important concept that is used for representing words for text analysis in the form of real-valued vectors. It is an advancement in NLP that has improved the ability of computers to understand text-based content in a better way.
#
#
# #### A little bit of history on word embeddings
# In 2013, Tomas Mikolov et al. developed an algorithm for learning word embeddings called **Word2vec** [[paper](https://arxiv.org/abs/1301.3781)][[code](https://code.google.com/archive/p/word2vec/)]. This algorithm uses a shallow neural network to learn word vectors so that the representation of each word of a given corpus is good at predicting its own contexts (Skip-Gram) or vice versa (CBOW).
#
# One year after the publication of Word2vec, Pennington et al. developed a new algorithm for learning word embeddings called **GloVe** [[paper](https://nlp.stanford.edu/pubs/glove.pdf)][[code](https://github.com/stanfordnlp/GloVe)]. This algorithm is based on the observation that word relationships can be recovered from the co-occurrence statistics of any (large enough) corpus.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid orange;background-color:#F3F3F3;color:#424242;">
#     <h3>Goal of today's exercise</h3><br/>
# In this exercise session, we will use both variants of these word embedding models (Word2Vec and GloVe) for our experiments.
# For the first part, we will train from scratch a Word2vec model with different datasets. In the second part, we will load pre-trained Word2vec and GloVe embeddings and test them on how well they capture concept similarity among words. Finally, for the last part, we will train a simple sentiment analysis classifier with these pre-trained embeddings as we discussed in the lecture.
#
# You will need to fill in all the missing pieces of code. For each one, you will be given a 🎯 `Goal` guidance that explains the steps you need to implement and a 💻 `API` reference with the functions or classes you can use to achieve each goal.
#
# </div>

# %%
# imported libraries for this exercise
import pandas as pd
import numpy as np
from gensim.test.utils import common_texts
from gensim.utils import tokenize   
from gensim.models import Word2Vec
import gensim.downloader
import torch 
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchmetrics.classification import BinaryAccuracy
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from gensim.corpora import WikiCorpus, MmCorpus
from gensim.test.utils import datapath, get_tmpfile
from gensim.utils import simple_preprocess

# %% [markdown]
# <a name="1"></a>
# ## 1. TASK A: Training a word embedding model from stratch
#
# In this part, you will train a model to learn vector representations of words and more specifically, we will train the word2vec model.
# To train the model we will use the Gensim library which is a free open-source Python library for representing documents as semantic vectors.
#
# > **Gensim** is designed to process raw, unstructured digital texts (“plain text”) using unsupervised machine learning algorithms. The algorithms in Gensim, such as Word2Vec, FastText, Latent Semantic Indexing (LSI, LSA, LsiModel), Latent Dirichlet Allocation (LDA, LdaModel) etc, automatically discover the semantic structure of documents by examining statistical co-occurrence patterns within a corpus of training documents. These algorithms are unsupervised, which means no human input is necessary – you only need a corpus of plain text documents.
# >
# > You can discover all Gensim functionalities [here](https://radimrehurek.com/gensim/index.html).
#
# To train your embedding model, you will need to instantiate Word2Vec and pass the data to the model to train with. We essentially need to pass on a list of lists, where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary.
#
# **Data:** We will train our embedding model using a toy dataset that is provided by the Gensim library. You can use the dataset under the following path `gensim.test.utils.common_texts`.

# %%
# bag of words for each sentence in toy dataset (imported from the gensim library in cell 2)
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
path_to_wiki_dump = datapath("enwiki-latest-pages-articles1.xml-p000000010p000030302-shortened.bz2")
corpus_path = get_tmpfile("wiki-corpus.mm")
wiki = WikiCorpus(path_to_wiki_dump)
sentences = []

for text in wiki.get_texts():
    sentences.append(text)   # already tokenized
# Out:
# c:\Users\leona\.virtualenvs\ModernNLP-CS552-zcopPU12\Lib\site-packages\gensim\utils.py:1332: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected %s; aliasing chunkize to chunkize_serial" % entity)

# %% [markdown]
# #### Train a Gensim Word2Vec model

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Train with `common_texts` dataset a Gensim word2vec model.<br>
#
# - 💻  **API:** You can use `gensim.models.Word2Vec` class.
# </div>

# %%
#instantiate and train model
w2v_model = Word2Vec(sentences=sentences, vector_size=100, window=5, min_count=1, workers=4)

# %%
w2v_simple = Word2Vec(sentences=common_texts, vector_size=100, window=5, min_count=1, workers=4)

# %%
# dict with vocabulary key indexes
words = w2v_model.wv.key_to_index
words
# Out:
# {'the': 0,
#  'of': 1,
#  'and': 2,
#  'in': 3,
#  'to': 4,
#  'is': 5,
#  'as': 6,
#  'for': 7,
#  'by': 8,
#  'that': 9,
#  'with': 10,
#  'was': 11,
#  'on': 12,
#  'are': 13,
#  'from': 14,
#  'an': 15,
#  'or': 16,
#  'it': 17,
#  'at': 18,
#  'be': 19,
#  'which': 20,
#  'his': 21,
#  'he': 22,
#  'this': 23,
#  'have': 24,
#  'not': 25,
#  'has': 26,
#  'were': 27,
#  'their': 28,
#  'also': 29,
#  'one': 30,
#  'other': 31,
#  'they': 32,
#  'but': 33,
#  'its': 34,
#  'had': 35,
#  'first': 36,
#  'more': 37,
#  'some': 38,
#  'been': 39,
#  'most': 40,
#  'all': 41,
#  'such': 42,
#  'can': 43,
#  'state': 44,
#  'after': 45,
#  'than': 46,
#  'used': 47,
#  'who': 48,
#  'two': 49,
#  'there': 50,
#  'may': 51,
#  'many': 52,
#  'when': 53,
#  'into': 54,
#  'new': 55,
#  'these': 56,
#  'time': 57,
#  'war': 58,
#  'during': 59,
#  'states': 60,
#  'only': 61,
#  'world': 62,
#  'apollo': 63,
#  'th': 64,
#  'about': 65,
#  'between': 66,
#  'would': 67,
#  'over': 68,
#  'while': 69,
#  'century': 70,
#  'no': 71,
#  'american': 72,
#  'art': 73,
#  'use': 74,
#  'lincoln': 75,
#  'number': 76,
#  'people': 77,
#  'north': 78,
#  'where': 79,
#  'united': 80,
#  'both': 81,
#  'through': 82,
#  'known': 83,
#  'however': 84,
#  'government': 85,
#  'form': 86,
#  'years': 87,
#  'national': 88,
#  'three': 89,
#  'british': 90,
#  'early': 91,
#  'so': 92,
#  'often': 93,
#  'them': 94,
#  'will': 95,
#  'country': 96,
#  'including': 97,
#  'well': 98,
#  'her': 99,
#  'if': 100,
#  'being': 101,
#  'year': 102,
#  'since': 103,
#  'up': 104,
#  'called': 105,
#  'because': 106,
#  'later': 107,
#  'any': 108,
#  'made': 109,
#  'court': 110,
#  'south': 111,
#  'population': 112,
#  'general': 113,
#  'before': 114,
#  'film': 115,
#  'alaska': 116,
#  'then': 117,
#  'angola': 118,
#  'part': 119,
#  'each': 120,
#  'found': 121,
#  'several': 122,
#  'under': 123,
#  'example': 124,
#  'water': 125,
#  'became': 126,
#  'although': 127,
#  'group': 128,
#  'international': 129,
#  'alabama': 130,
#  'based': 131,
#  'language': 132,
#  'aristotle': 133,
#  'human': 134,
#  'einstein': 135,
#  'work': 136,
#  'system': 137,
#  'out': 138,
#  'order': 139,
#  'university': 140,
#  'those': 141,
#  'include': 142,
#  'him': 143,
#  'city': 144,
#  'high': 145,
#  'could': 146,
#  'history': 147,
#  'modern': 148,
#  'greek': 149,
#  'albania': 150,
#  'large': 151,
#  'due': 152,
#  'life': 153,
#  'name': 154,
#  'according': 155,
#  'azerbaijan': 156,
#  'among': 157,
#  'acid': 158,
#  'same': 159,
#  'until': 160,
#  'four': 161,
#  'what': 162,
#  'common': 163,
#  'major': 164,
#  'second': 165,
#  'union': 166,
#  'like': 167,
#  'languages': 168,
#  'different': 169,
#  'french': 170,
#  'much': 171,
#  'she': 172,
#  'achilles': 173,
#  'long': 174,
#  'army': 175,
#  'even': 176,
#  'social': 177,
#  'earth': 178,
#  'do': 179,
#  'alberta': 180,
#  'control': 181,
#  'land': 182,
#  'small': 183,
#  'alkali': 184,
#  'animal': 185,
#  'us': 186,
#  'president': 187,
#  'against': 188,
#  'species': 189,
#  'development': 190,
#  'another': 191,
#  'very': 192,
#  'political': 193,
#  'agassi': 194,
#  'largest': 195,
#  'great': 196,
#  'within': 197,
#  'america': 198,
#  'autism': 199,
#  'god': 200,
#  'others': 201,
#  'million': 202,
#  'non': 203,
#  'abortion': 204,
#  'using': 205,
#  'around': 206,
#  'following': 207,
#  'military': 208,
#  'schopenhauer': 209,
#  'john': 210,
#  'term': 211,
#  'animals': 212,
#  'see': 213,
#  'space': 214,
#  'area': 215,
#  'asia': 216,
#  'groups': 217,
#  'end': 218,
#  'way': 219,
#  'study': 220,
#  'now': 221,
#  'east': 222,
#  'congress': 223,
#  'developed': 224,
#  'rand': 225,
#  'less': 226,
#  'theory': 227,
#  'considered': 228,
#  'isbn': 229,
#  'european': 230,
#  'day': 231,
#  'oil': 232,
#  'metals': 233,
#  'usually': 234,
#  'production': 235,
#  'various': 236,
#  'did': 237,
#  'set': 238,
#  'word': 239,
#  'west': 240,
#  'book': 241,
#  'forces': 242,
#  'countries': 243,
#  'body': 244,
#  'river': 245,
#  'per': 246,
#  'similar': 247,
#  'own': 248,
#  'sea': 249,
#  'anthropology': 250,
#  'we': 251,
#  'important': 252,
#  'began': 253,
#  'philosophy': 254,
#  'children': 255,
#  'men': 256,
#  'science': 257,
#  'energy': 258,
#  'natural': 259,
#  'without': 260,
#  'make': 261,
#  'still': 262,
#  'systems': 263,
#  'areas': 264,
#  'anarchist': 265,
#  'central': 266,
#  'africa': 267,
#  'power': 268,
#  'afghanistan': 269,
#  'air': 270,
#  'europe': 271,
#  'society': 272,
#  'works': 273,
#  'southern': 274,
#  'open': 275,
#  'late': 276,
#  'back': 277,
#  'school': 278,
#  'research': 279,
#  'though': 280,
#  'sometimes': 281,
#  'agricultural': 282,
#  'related': 283,
#  'force': 284,
#  'andorra': 285,
#  'western': 286,
#  'public': 287,
#  'region': 288,
#  'point': 289,
#  'place': 290,
#  'academy': 291,
#  'either': 292,
#  'york': 293,
#  'black': 294,
#  'few': 295,
#  'independence': 296,
#  'de': 297,
#  'local': 298,
#  'times': 299,
#  'period': 300,
#  'main': 301,
#  'thus': 302,
#  'members': 303,
#  'party': 304,
#  'man': 305,
#  'must': 306,
#  'white': 307,
#  'published': 308,
#  'led': 309,
#  'left': 310,
#  'along': 311,
#  'support': 312,
#  'republic': 313,
#  'food': 314,
#  'means': 315,
#  'education': 316,
#  'become': 317,
#  'established': 318,
#  'case': 319,
#  'english': 320,
#  'thought': 321,
#  'agriculture': 322,
#  'how': 323,
#  'soviet': 324,
#  'algeria': 325,
#  'family': 326,
#  'data': 327,
#  'free': 328,
#  'music': 329,
#  'metal': 330,
#  'albanian': 331,
#  'island': 332,
#  'algorithm': 333,
#  'five': 334,
#  'held': 335,
#  'result': 336,
#  'animation': 337,
#  'alphabet': 338,
#  'given': 339,
#  'last': 340,
#  'numbers': 341,
#  'best': 342,
#  'certain': 343,
#  'law': 344,
#  'generally': 345,
#  'health': 346,
#  'present': 347,
#  'elements': 348,
#  'meaning': 349,
#  'especially': 350,
#  'wrote': 351,
#  'moon': 352,
#  'total': 353,
#  'effect': 354,
#  'george': 355,
#  'further': 356,
#  'civil': 357,
#  'particular': 358,
#  'farm': 359,
#  'northern': 360,
#  'having': 361,
#  'forms': 362,
#  'series': 363,
#  'does': 364,
#  'alkanes': 365,
#  'algae': 366,
#  'crew': 367,
#  'mission': 368,
#  'good': 369,
#  'lower': 370,
#  'single': 371,
#  'list': 372,
#  'ancient': 373,
#  'studies': 374,
#  'atlantic': 375,
#  'character': 376,
#  'terms': 377,
#  'technology': 378,
#  'external': 379,
#  'near': 380,
#  'took': 381,
#  'every': 382,
#  'analysis': 383,
#  'down': 384,
#  'age': 385,
#  'bc': 386,
#  'algorithms': 387,
#  'atomic': 388,
#  'washington': 389,
#  'surface': 390,
#  'third': 391,
#  'latin': 392,
#  'movement': 393,
#  'cause': 394,
#  'alchemy': 395,
#  'articles': 396,
#  'low': 397,
#  'culture': 398,
#  'line': 399,
#  'change': 400,
#  'letters': 401,
#  'average': 402,
#  'press': 403,
#  'field': 404,
#  'cultural': 405,
#  'process': 406,
#  'anarchism': 407,
#  'aruba': 408,
#  'african': 409,
#  'ocean': 410,
#  'little': 411,
#  'should': 412,
#  'live': 413,
#  'death': 414,
#  'carbon': 415,
#  'head': 416,
#  'economic': 417,
#  'standard': 418,
#  'included': 419,
#  'awards': 420,
#  'battle': 421,
#  'mean': 422,
#  'making': 423,
#  'economy': 424,
#  'rather': 425,
#  'province': 426,
#  'model': 427,
#  'created': 428,
#  'won': 429,
#  'july': 430,
#  'right': 431,
#  'said': 432,
#  'women': 433,
#  'tarkovsky': 434,
#  'produced': 435,
#  'available': 436,
#  'higher': 437,
#  'territory': 438,
#  'institute': 439,
#  'home': 440,
#  'old': 441,
#  'april': 442,
#  'americans': 443,
#  'significant': 444,
#  'france': 445,
#  'aberdeen': 446,
#  'constitution': 447,
#  'lunar': 448,
#  'references': 449,
#  'medical': 450,
#  'evidence': 451,
#  'words': 452,
#  'short': 453,
#  'current': 454,
#  'just': 455,
#  'russian': 456,
#  'empire': 457,
#  'rate': 458,
#  'parts': 459,
#  'influence': 460,
#  'acids': 461,
#  'written': 462,
#  'possible': 463,
#  'spanish': 464,
#  'person': 465,
#  'self': 466,
#  'roman': 467,
#  'middle': 468,
#  'living': 469,
#  'computer': 470,
#  'light': 471,
#  'formed': 472,
#  'schools': 473,
#  'huxley': 474,
#  'popular': 475,
#  'links': 476,
#  'almost': 477,
#  'ascii': 478,
#  'capital': 479,
#  'official': 480,
#  'characters': 481,
#  'appeal': 482,
#  'india': 483,
#  'original': 484,
#  'named': 485,
#  'strong': 486,
#  'foreign': 487,
#  'throughout': 488,
#  'off': 489,
#  'march': 490,
#  'revolution': 491,
#  'hydrogen': 492,
#  'anatomy': 493,
#  'son': 494,
#  'december': 495,
#  'male': 496,
#  'across': 497,
#  'final': 498,
#  'individual': 499,
#  'fish': 500,
#  'temple': 501,
#  'mostly': 502,
#  'base': 503,
#  'next': 504,
#  'portuguese': 505,
#  'company': 506,
#  'letter': 507,
#  'problems': 508,
#  'treatment': 509,
#  'described': 510,
#  'films': 511,
#  'county': 512,
#  'above': 513,
#  'writing': 514,
#  'take': 515,
#  'religion': 516,
#  'china': 517,
#  'motion': 518,
#  'file': 519,
#  'house': 520,
#  'continental': 521,
#  'service': 522,
#  'specific': 523,
#  'estimated': 524,
#  'today': 525,
#  'our': 526,
#  'lost': 527,
#  'william': 528,
#  'native': 529,
#  'center': 530,
#  'type': 531,
#  'effects': 532,
#  'king': 533,
#  'role': 534,
#  'canada': 535,
#  'religious': 536,
#  'days': 537,
#  'growth': 538,
#  'greater': 539,
#  'increased': 540,
#  'september': 541,
#  'far': 542,
#  'german': 543,
#  'structure': 544,
#  'program': 545,
#  'ideas': 546,
#  'outside': 547,
#  'amphibians': 548,
#  'side': 549,
#  'traditional': 550,
#  'least': 551,
#  'spacecraft': 552,
#  'gas': 553,
#  'climate': 554,
#  'regions': 555,
#  'level': 556,
#  'troops': 557,
#  'robert': 558,
#  'action': 559,
#  'followed': 560,
#  'post': 561,
#  'method': 562,
#  'rights': 563,
#  'angolan': 564,
#  'standards': 565,
#  'november': 566,
#  'albedo': 567,
#  'physical': 568,
#  'techniques': 569,
#  'addition': 570,
#  'seen': 571,
#  'eastern': 572,
#  'came': 573,
#  'limited': 574,
#  'uses': 575,
#  'half': 576,
#  'cases': 577,
#  'believed': 578,
#  'johnston': 579,
#  'together': 580,
#  'range': 581,
#  'includes': 582,
#  'increase': 583,
#  'january': 584,
#  'young': 585,
#  'february': 586,
#  'special': 587,
#  'taken': 588,
#  'themselves': 589,
#  'cities': 590,
#  'approximately': 591,
#  'itself': 592,
#  'nation': 593,
#  'built': 594,
#  'version': 595,
#  'function': 596,
#  'changes': 597,
#  'information': 598,
#  'proposed': 599,
#  'associated': 600,
#  'majority': 601,
#  'ii': 602,
#  'instead': 603,
#  'sodium': 604,
#  'award': 605,
#  'highest': 606,
#  'typically': 607,
#  'methods': 608,
#  'love': 609,
#  'act': 610,
#  'st': 611,
#  'nature': 612,
#  'whether': 613,
#  'islamic': 614,
#  'song': 615,
#  'born': 616,
#  'seven': 617,
#  'lithium': 618,
#  'afghan': 619,
#  'jpg': 620,
#  'never': 621,
#  'moved': 622,
#  'former': 623,
#  'once': 624,
#  'association': 625,
#  'size': 626,
#  'six': 627,
#  'therefore': 628,
#  'value': 629,
#  'position': 630,
#  'policy': 631,
#  'derived': 632,
#  'aikido': 633,
#  'adobe': 634,
#  'flight': 635,
#  'top': 636,
#  'reported': 637,
#  'church': 638,
#  'despite': 639,
#  'continued': 640,
#  'able': 641,
#  'anti': 642,
#  'defined': 643,
#  'altruism': 644,
#  'training': 645,
#  'located': 646,
#  'recent': 647,
#  'member': 648,
#  'trade': 649,
#  'legal': 650,
#  'return': 651,
#  'required': 652,
#  'stage': 653,
#  'help': 654,
#  'co': 655,
#  'examples': 656,
#  'experience': 657,
#  'james': 658,
#  'himself': 659,
#  'divided': 660,
#  'caesium': 661,
#  'you': 662,
#  'command': 663,
#  'billion': 664,
#  'gave': 665,
#  'script': 666,
#  'names': 667,
#  'direct': 668,
#  'october': 669,
#  'upon': 670,
#  'sense': 671,
#  'arabic': 672,
#  'scientific': 673,
#  'television': 674,
#  'practice': 675,
#  'provided': 676,
#  'spain': 677,
#  'paris': 678,
#  'potassium': 679,
#  'gold': 680,
#  'literature': 681,
#  'red': 682,
#  'notes': 683,
#  'produce': 684,
#  'humans': 685,
#  'reason': 686,
#  'orbit': 687,
#  'anova': 688,
#  'title': 689,
#  'code': 690,
#  'courts': 691,
#  'material': 692,
#  'problem': 693,
#  'students': 694,
#  'nations': 695,
#  'atoms': 696,
#  'astronauts': 697,
#  'novel': 698,
#  'properties': 699,
#  'table': 700,
#  'independent': 701,
#  'hand': 702,
#  'beginning': 703,
#  'solution': 704,
#  'arts': 705,
#  'community': 706,
#  'media': 707,
#  'primary': 708,
#  'interest': 709,
#  'britain': 710,
#  'organization': 711,
#  'introduced': 712,
#  'fields': 713,
#  'definition': 714,
#  'show': 715,
#  'kingdom': 716,
#  'hours': 717,
#  'class': 718,
#  'view': 719,
#  'azerbaijani': 720,
#  'electron': 721,
#  'received': 722,
#  'indian': 723,
#  'mass': 724,
#  'products': 725,
#  'objects': 726,
#  'lack': 727,
#  'fact': 728,
#  'months': 729,
#  'mother': 730,
#  'true': 731,
#  'afroasiatic': 732,
#  'charge': 733,
#  'june': 734,
#  'industry': 735,
#  'remained': 736,
#  'largely': 737,
#  'alexander': 738,
#  'variety': 739,
#  'peace': 740,
#  'basic': 741,
#  'complex': 742,
#  'px': 743,
#  'chemical': 744,
#  'thomas': 745,
#  'test': 746,
#  'factors': 747,
#  'highly': 748,
#  'primarily': 749,
#  'august': 750,
#  'always': 751,
#  'individuals': 752,
#  'philosopher': 753,
#  'types': 754,
#  'chinese': 755,
#  'office': 756,
#  'brought': 757,
#  'reading': 758,
#  'books': 759,
#  'events': 760,
#  'federal': 761,
#  'abortions': 762,
#  'animated': 763,
#  'element': 764,
#  'career': 765,
#  'team': 766,
#  'female': 767,
#  'equal': 768,
#  'slavery': 769,
#  'father': 770,
#  'whose': 771,
#  'close': 772,
#  'nearly': 773,
#  'issues': 774,
#  'republican': 775,
#  'edmonton': 776,
#  'sciences': 777,
#  'elected': 778,
#  'building': 779,
#  'mobile': 780,
#  'nasa': 781,
#  'widely': 782,
#  'might': 783,
#  'run': 784,
#  'influenced': 785,
#  'basis': 786,
#  'cannot': 787,
#  'confederation': 788,
#  'london': 789,
#  'christian': 790,
#  'relations': 791,
#  'abacus': 792,
#  'frogs': 793,
#  'larger': 794,
#  'eggs': 795,
#  'mainly': 796,
#  'concept': 797,
#  'services': 798,
#  'paper': 799,
#  'democratic': 800,
#  'relationship': 801,
#  'provide': 802,
#  'richard': 803,
#  'pacific': 804,
#  'symbols': 805,
#  'need': 806,
#  'source': 807,
#  'tax': 808,
#  'values': 809,
#  'rest': 810,
#  'david': 811,
#  'election': 812,
#  'idea': 813,
#  'eventually': 814,
#  'complete': 815,
#  'amateur': 816,
#  'chain': 817,
#  'plant': 818,
#  'coast': 819,
#  'effective': 820,
#  'weeks': 821,
#  'performed': 822,
#  'move': 823,
#  'russia': 824,
#  'personal': 825,
#  'conditions': 826,
#  'resources': 827,
#  'revolutionary': 828,
#  'algerian': 829,
#  'allah': 830,
#  'ever': 831,
#  'appellate': 832,
#  'supreme': 833,
#  'construction': 834,
#  'legislature': 835,
#  'contains': 836,
#  'probably': 837,
#  'internal': 838,
#  'referred': 839,
#  'albert': 840,
#  'ground': 841,
#  'saw': 842,
#  'leading': 843,
#  'away': 844,
#  'salamanders': 845,
#  'highway': 846,
#  'census': 847,
#  'smaller': 848,
#  'remains': 849,
#  'care': 850,
#  'whole': 851,
#  'henry': 852,
#  'discovered': 853,
#  'knowledge': 854,
#  'global': 855,
#  'create': 856,
#  'full': 857,
#  'particularly': 858,
#  'technique': 859,
#  'edition': 860,
#  'reached': 861,
#  'elections': 862,
#  'below': 863,
#  'summer': 864,
#  'better': 865,
#  'green': 866,
#  'simple': 867,
#  'security': 868,
#  'colonies': 869,
#  'latter': 870,
#  'died': 871,
#  'give': 872,
#  'famous': 873,
#  'alchemical': 874,
#  'trial': 875,
#  'valley': 876,
#  'plants': 877,
#  'separate': 878,
#  'points': 879,
#  'earlier': 880,
#  'causes': 881,
#  'play': 882,
#  'style': 883,
#  'understanding': 884,
#  'subject': 885,
#  'scale': 886,
#  'behind': 887,
#  'killed': 888,
#  'active': 889,
#  'text': 890,
#  'freedom': 891,
#  'put': 892,
#  'ansi': 893,
#  'my': 894,
#  'spoken': 895,
#  'moving': 896,
#  'originally': 897,
#  'aardvark': 898,
#  'compounds': 899,
#  'applied': 900,
#  'wide': 901,
#  'operations': 902,
#  'caused': 903,
#  'communities': 904,
#  'towards': 905,
#  'future': 906,
#  'night': 907,
#  'politics': 908,
#  'working': 909,
#  'council': 910,
#  'reaction': 911,
#  'property': 912,
#  'centuries': 913,
#  'mid': 914,
#  'ions': 915,
#  'electrons': 916,
#  'dutch': 917,
#  'length': 918,
#  'fort': 919,
#  'birmingham': 920,
#  'represented': 921,
#  'semitic': 922,
#  'soil': 923,
#  'activities': 924,
#  'things': 925,
#  'california': 926,
#  'shown': 927,
#  'served': 928,
#  'sent': 929,
#  'appointed': 930,
#  'access': 931,
#  'season': 932,
#  'governor': 933,
#  'come': 934,
#  'farming': 935,
#  'relatively': 936,
#  'features': 937,
#  'object': 938,
#  'library': 939,
#  'mountain': 940,
#  'child': 941,
#  'laws': 942,
#  'historical': 943,
#  'front': 944,
#  'supported': 945,
#  'structures': 946,
#  'resulting': 947,
#  'numerous': 948,
#  'product': 949,
#  'private': 950,
#  'muslim': 951,
#  'anarchists': 952,
#  'orwell': 953,
#  'units': 954,
#  'parliament': 955,
#  'radio': 956,
#  'football': 957,
#  'expected': 958,
#  'signed': 959,
#  'border': 960,
#  'past': 961,
#  'record': 962,
#  'color': 963,
#  'era': 964,
#  'loss': 965,
#  'results': 966,
#  'suggested': 967,
#  'bank': 968,
#  'woman': 969,
#  'attack': 970,
#  'branch': 971,
#  'ability': 972,
#  'distribution': 973,
#  'response': 974,
#  'turn': 975,
#  'scholars': 976,
#  'sources': 977,
#  'birth': 978,
#  'physics': 979,
#  'machine': 980,
#  'armstrong': 981,
#  'blood': 982,
#  'chief': 983,
#  'confederate': 984,
#  'find': 985,
#  'difficult': 986,
#  'asd': 987,
#  'review': 988,
#  'mind': 989,
#  'classical': 990,
#  'again': 991,
#  'principle': 992,
#  'involved': 993,
#  'decided': 994,
#  'germany': 995,
#  'matter': 996,
#  'joseph': 997,
#  'module': 998,
#  'landing': 999,
#  ...}

# %% [markdown]
# #### Find word similarities

# %%
# explore embeddings
vector = w2v_model.wv['computer']  # get numpy vector of a word
print('The vector length of the word is {}.'.format(len(vector)))
# Out:
# The vector length of the word is 100.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Use the trained word2vec model to find most similar words for token _"computer"_.
# - 💻 **API:** You can use Gensim's `.most_similar` function.
#
# </div>

# %%
w2v_model.wv.most_similar(positive=vector)
# Out:
# [('computer', 1.0),
#  ('organic', 0.9981057047843933),
#  ('pure', 0.9980127215385437),
#  ('ethical', 0.9980126619338989),
#  ('using', 0.9979830384254456),
#  ('ions', 0.9979469776153564),
#  ('points', 0.9975471496582031),
#  ('linear', 0.9974820613861084),
#  ('potassium', 0.9974666237831116),
#  ('sequence', 0.9974292516708374)]

# %%
w2v_simple.wv.most_similar(positive=w2v_simple.wv['computer'])
# Out:
# [('computer', 0.9999999403953552),
#  ('system', 0.21617139875888824),
#  ('survey', 0.04468923062086105),
#  ('interface', 0.015203387476503849),
#  ('time', 0.0019510677084326744),
#  ('trees', -0.03284316137433052),
#  ('human', -0.0742427185177803),
#  ('response', -0.09317591041326523),
#  ('graph', -0.09575342386960983),
#  ('eps', -0.10513807088136673)]

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Play around with initial settings
#
# - Re-train the model with different datasets ( [Wikipedia](https://radimrehurek.com/gensim/corpora/wikicorpus.html), [Opinosis](https://radimrehurek.com/gensim/corpora/opinosiscorpus.html) ) and vector sizes and run similarity with different top-n. How would you comment on the results?
# - Think about the limitations of the Word2vec approach.
#
# </div>

# %% [markdown]
# ***--- YOU CAN WRITE YOU ANSWER HERE ---***
#
# it mixes similarity with contextual words, for example "using" and "computer"

# %% [markdown]
# <a name="2"></a>
# ## 2. TASK B: Word embedding similarity
#
# For this task, we will use pre-trained word embedding models.
#
# **Word2Vec:** We will use once again Word2vec as in the previous question, but in this case we will load the pre-trained version of it that has been trained on a part of the Google News dataset (about 100 billion words). The model variant that we will use, contains 300-dimensional vectors for 3 million words and phrases.
#
# **GloVe:** We will also use GloVe word embeddings that have been pre-trained on 2B tweets, 27B tokens, 1.2M vocab, uncased. The model variant that we will use contains 100-dimensional vectors.
#
# Once we load the vector represenation of words, we will:
# - find similarities between group of words.
# - discover a very cool property of word embeddings through analogies.
# - evaluate their performance on how well they capture the semantics between words on the SimLex task.

# %% [markdown]
# ### 2.1 Using pre-trained word embedding models

# %%
# Show all available models in gensim-data
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
# Download the "word2vec-google-news-300" embeddings
w2v_vectors = gensim.downloader.load('word2vec-google-news-300')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Download the "word2vec-google-news-300" embeddings
# ----> 2 w2v_vectors = gensim.downloader.load('word2vec-google-news-300')
#
# File c:\Users\leona\.virtualenvs\ModernNLP-CS552-zcopPU12\Lib\site-packages\gensim\downloader.py:503, in load(name, return_path)
#     501 sys.path.insert(0, BASE_DIR)
#     502 module = __import__(name)
# --> 503 return module.load_data()
#
# File ~/gensim-data\word2vec-google-news-300\__init__.py:8, in load_data()
#       6 def load_data():
#       7     path = os.path.join(base_dir, 'word2vec-google-news-300', "word2vec-google-news-300.gz")
# ----> 8     model = KeyedVectors.load_word2vec_format(path, binary=True)
#       9     return model
#
# File c:\Users\leona\.virtualenvs\ModernNLP-CS552-zcopPU12\Lib\site-packages\gensim\models\keyedvectors.py:1721, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1674 @classmethod
#    1675 def load_word2vec_format(
#    1676         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1677         limit=None, datatype=REAL, no_header=False,
#    1678     ):
#    1679     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1680
#    1681     Warnings
#    (...)   1719
#    1720     """
# -> 1721     return _load_word2vec_format(
#    1722         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1723         limit=limit, datatype=datatype, no_header=no_header,
#    1724     )
#
# File c:\Users\leona\.virtualenvs\ModernNLP-CS552-zcopPU12\Lib\site-packages\gensim\models\keyedvectors.py:2067, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2064 kv = cls(vector_size, vocab_size, dtype=datatype)
#    2066 if binary:
# -> 2067     _word2vec_read_binary(
#    2068         fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding
#    2069     )
#    2070 else:
#    2071     _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File c:\Users\leona\.virtualenvs\ModernNLP-CS552-zcopPU12\Lib\site-packages\gensim\models\keyedvectors.py:1960, in _word2vec_read_binary(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding)
#    1957 tot_processed_words = 0
#    1959 while tot_processed_words < vocab_size:
# -> 1960     new_chunk = fin.read(binary_chunk_size)
#    1961     chunk += new_chunk
#    1962     processed_words, chunk = _add_bytes_to_kv(
#    1963         kv, counts, chunk, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\gzip.py:340, in GzipFile.read(self, size)
#     338     import errno
#     339     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 340 return self._buffer.read(size)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\gzip.py:556, in _GzipReader.read(self, size)
#     554     uncompress = self._decompressor.decompress(buf, size)
#     555 else:
# --> 556     uncompress = self._decompressor.decompress(b"", size)
#     558 if self._decompressor.unused_data != b"":
#     559     # Prepend the already read bytes to the fileobj so they can
#     560     # be seen by _read_eof() and _read_gzip_header()
#     561     self._fp.prepend(self._decompressor.unused_data)
#
# KeyboardInterrupt:

# %%
# Download the "glove-wiki-gigaword-100" embeddings
glove_vectors = gensim.downloader.load('glove-wiki-gigaword-100')

# %% [markdown]
# The best way to understand a data is by visualizing them. We will use t-SNE to reduce the data with 300 dimensions to 2 dimensions, so that we can plot the data on our screens.
# t-SNE is a non-linear dimensionality reduction algorithm that attempts to represent high-dimensional data and the underlying relationships between vectors in a lower-dimensional space.

# %%
# visualization utility function. NO NEED TO CHANGE ANYTHING HERE
sns.set_style('whitegrid')
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

def tsne_scatterplot(model, search_word, topn):
    labels = [search_word]
    tokens = [model[search_word]]
    similar = [1]
    close_words = model.similar_by_word(search_word, topn=topn)
    for word in close_words:
        tokens.append(model[word[0]])
        labels.append(word[0])
        similar.append(word[1])

    tsne_model = TSNE(n_components=2, perplexity=topn, init='pca')
    coordinates = tsne_model.fit_transform(np.array(tokens))
    df = pd.DataFrame({'x': [x for x in coordinates[:, 0]],
                       'y': [y for y in coordinates[:, 1]],
                       'words': labels,
                       'similarity': similar}
                      )
    fig, ax = plt.subplots()
    plot = ax.scatter(df.x, df.y, c=df.similarity, cmap='Reds')
    for i in range(len(df)):
        ax.annotate("  {} ({:.2f})".format(df.words[i].title(),
                                           df.similarity[i]),
                    (df.x[i], df.y[i]))

    plt.colorbar(mappable=plot, ax=ax)
    plt.title('t-SNE visualization for {}'.format(search_word))
    plt.show()

# %%
# visualize the most similar words for a given word.
tsne_scatterplot(glove_vectors, "computer", 20)

# %% [markdown]
# #### Interactive visualization
#
# In the following link, you can explore the state-of-the-art models in an interactive embedding visualization: https://projector.tensorflow.org/.
#
# Using the Embedding Projector, you can graphically represent high dimensional embeddings. This can be helpful in visualizing, examining, and understanding your embeddings.
#
# Give it a try! Test interesting clusters of similar words!

# %% [markdown]
# ### 2.2 Check word analogies
#
# The fact that we can analyze the use of words in language to deduce their meaning is a fundamental idea of [distributional semantics](https://en.wikipedia.org/wiki/Distributional_semantics). This is the inspiration behind many algorithms for learning numerical representations of words (word embeddings). An important aspect of these representations is the ability to solve word analogies of the form “A is to B what C is to X” using simple arithmetic. This is generally simplified as “King — Man + Woman $\sim$ Queen.
#
# In this subquestion we will explore interesting relations that can be extracted from word embeddings. You will be given semantic relations and you need to implement the respective code using the embedding model.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Use the pre-trained GloVe embeddings to implement the following analogies.
# - 💻 **API:** You can use Gensim's `.most_similar` function.
#
# </div>

# %% [markdown]
# **Analogy A:**  `King` — `Man` + `Woman` ~ `?`
#
# `?`: `Queen`

# %%
glove_vectors.most_similar(positive=["woman", "king"], negative=["man"])
# Out:
# [('queen', 0.7698540687561035),
#  ('monarch', 0.6843381524085999),
#  ('throne', 0.6755736470222473),
#  ('daughter', 0.6594556570053101),
#  ('princess', 0.6520534157752991),
#  ('prince', 0.6517034769058228),
#  ('elizabeth', 0.6464517712593079),
#  ('mother', 0.631171703338623),
#  ('emperor', 0.6106470823287964),
#  ('wife', 0.6098655462265015)]

# %% [markdown]
# **Analogy B:**  `France` — `Paris` + `Athens` ~ `?`
#
# `?`: `Greece`

# %%
glove_vectors.most_similar(positive=["france", "athens"], negative=["paris"])
# Out:
# [('greece', 0.7968204617500305),
#  ('finland', 0.6545611023902893),
#  ('turkey', 0.6506675481796265),
#  ('bulgaria', 0.6442033648490906),
#  ('romania', 0.6315340995788574),
#  ('estonia', 0.6312719583511353),
#  ('portugal', 0.6253728866577148),
#  ('cyprus', 0.625159502029419),
#  ('macedonia', 0.6197173595428467),
#  ('olympics', 0.6187255382537842)]

# %% [markdown]
# However, we should not forget that these models are trained in human generated language. Meaning that societal and demographic biases are inevitable. In the following example you will witness these kinds of biases in the final output.
#
# Fortunately, extensive research has been done to tackle this issue trying to de-bias the embeddings models. More regarding this topic will be covered in Week 10 when we will talk about Ethics in NLP regarding Toxicity, Bias and Fairness.
#
# **Analogy C:**  `Doctor` - `Man` + `Woman` ~ `Nurse`

# %%
glove_vectors.most_similar(positive=["doctor", "woman"], negative=["man"])
# Out:
# [('nurse', 0.7735227942466736),
#  ('physician', 0.7189430594444275),
#  ('doctors', 0.6824328303337097),
#  ('patient', 0.6750683188438416),
#  ('dentist', 0.6726033091545105),
#  ('pregnant', 0.6642459630966187),
#  ('medical', 0.6520450115203857),
#  ('nursing', 0.645348072052002),
#  ('mother', 0.63933265209198),
#  ('hospital', 0.6387495994567871)]

# %% [markdown]
# ### 2.3 Evaluate different models with SimLex
#
# In this part of the exercise, we will evaluate the syntactic concreteness of the created vectors using their similarity. For this task, we will use the SimLex999 dataset which is a human-annotated dataset regarding the similarity of concepts of words.
#
# - 📄 Paper: https://aclanthology.org/J15-4004.pdf
# - 👾 More about the task: https://fh295.github.io/simlex.html
#
# > - Download the data from [here](https://fh295.github.io/SimLex-999.zip)
# > - Unzip the file and put the corresponding folder with the dataset in the same dir as this notebook
#
# SimLex-999 is a gold standard resource for the evaluation of models that learn the meaning of words and concepts. SimLex-999 provides a way of measuring how well models capture similarity, rather than relatedness or association.
#
# #### Dataset:
# SimLex-999.txt is a tab-separated plaintext file, where rows correspond to concept pairs and columns correspond to the properties of each pair.
#
# |Column | Description |
# |-------|:-------------|
# |word1| The first concept in the pair.|
# |word2| The second concept in the pair. Note that the order is only relevant to the column Assoc(USF). These values (free association scores) are asymmetric. All other values are symmetric properties independent of the ordering word1, word2.|
# |POS| The majority part-of-speech of the concept words, as determined by occurrence in the POS-tagged British National Corpus. Only pairs of matching POS are included in SimLex-999.|
# |SimLex999 | The SimLex999 similarity rating. Note that average annotator scores have been (linearly) mapped from the range [0,6] to the range [0,10] to match other datasets such as WordSim-353. |
# |conc(w1)| The concreteness rating of word1 on a scale of 1-7. Taken from the University of South Florida Free Association Norms database. |
# |conc(w2)| The concreteness rating of word2 on a scale of 1-7. Taken from the University of South Florida Free Association Norms database.|
# |concQ| The quartile the pair occupies based on the two concreteness ratings. Used for some analyses in the above paper.|
# |Assoc(USF)| The strength of free association from word1 to word2. Values are taken from the University of South Florida Free Association Dataset.|
# |SimAssoc333| Binary indicator of whether the pair is one of the 333 most associated in the dataset (according to Assoc(USF)). This subset of SimLex999 is often the hardest for computational models to capture because the noise from high association can confound the similarity rating. See the paper for more details.|
# |SD(SimLex)| The standard deviation of annotator scores when rating this pair. Low values indicate good agreement between the 15+ annotators on the similarity value SimLex999. Higher scores indicate less certainty. |

# %% [markdown]
# We will be using the **`SimLex999` similarity column** to evaluate our word embeddings on this dataset. We will select the top 50 most similar pairs according to simlex999 column which a score from 0 to 10 regarding the similarities of the two words (columns: word1, word2) and it has been annotated by humans. On this subset of data, we will find the similarity score of the two words using our two pre-trained embedding models (Word2Vec, GloVe).

# %%
# read data
simlex = pd.read_csv('SimLex-999.txt', delimiter='\t')
simlex = simlex[['word1', 'word2', 'SimLex999']]
simlex.head()
# Out:
#    word1        word2  SimLex999
# 0    old          new       1.58
# 1  smart  intelligent       9.20
# 2   hard    difficult       8.77
# 3  happy     cheerful       9.55
# 4   hard         easy       0.95

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Print the min, avg and max values of SimLex999 score.
#
# </div>

# %%
simlex["SimLex999"].min(), simlex["SimLex999"].mean(), simlex["SimLex999"].max()
# Out:
# (np.float64(0.23), np.float64(4.561571571571572), np.float64(9.8))

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Select the top 50 pairs with the highest SimLex similarity score.
# </div>

# %%
simlex_sorted = simlex.sort_values(by="SimLex999", ascending=False).iloc[:50,:]
simlex_sorted
# Out:
#            word1        word2  SimLex999
# 782       vanish    disappear       9.80
# 22         quick        rapid       9.70
# 205      creator        maker       9.62
# 8         stupid         dumb       9.58
# 16        insane        crazy       9.57
# 3          happy     cheerful       9.55
# 42         large          big       9.55
# 140          cow       cattle       9.52
# 134         area       region       9.47
# 18         large         huge       9.47
# 28        simple         easy       9.40
# 71       bizarre      strange       9.37
# 121      student        pupil       9.35
# 234     attorney       lawyer       9.35
# 781        occur       happen       9.32
# 162      hallway     corridor       9.28
# 799       inform       notify       9.25
# 128      teacher   instructor       9.25
# 34         weird          odd       9.20
# 143         taxi          cab       9.20
# 1          smart  intelligent       9.20
# 65        scarce         rare       9.17
# 529      drizzle         rain       9.17
# 6          happy         glad       9.17
# 786      protect       defend       9.13
# 784        plead          beg       9.08
# 298     boundary       border       9.08
# 885      declare     announce       9.08
# 442    adversary     opponent       9.05
# 165          cop      sheriff       9.05
# 385  corporation     business       9.02
# 352         pact    agreement       9.02
# 25       strange          odd       9.02
# 236     business      company       9.02
# 186      victory      triumph       8.98
# 59     essential    necessary       8.97
# 265    abundance       plenty       8.97
# 9          weird      strange       8.93
# 370    physician       doctor       8.88
# 592      journey         trip       8.88
# 541         task          job       8.87
# 129        movie         film       8.87
# 816       decide       choose       8.87
# 819         roam       wander       8.83
# 285        shore        coast       8.83
# 839      acquire          get       8.82
# 62       crucial    important       8.82
# 945  contemplate        think       8.82
# 120       friend        buddy       8.78
# 303      heroine         hero       8.78

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** For each word pair from `simlex_similar_pairs`, compute the similarity between the GloVe embeddings (also Word2Vec embeddings) of the words.
# - 💻 **API:** You can use Gensim's `.similarity` function.
#
# </div>

# %%
import pandas as pd

rows = []

for _, row in simlex_sorted.iterrows():
    w1 = row["word1"]
    w2 = row["word2"]

    if w1 in glove_vectors and w2 in glove_vectors:
        sim_glo = glove_vectors.similarity(w1, w2)
        sim_w2v = w2v_vectors.similarity(w1, w2)
    else:
        sim_glo = None
        sim_w2v = None

    rows.append({
        "word1": w1,
        "word2": w2,
        "similarity_glove": sim_glo,
        "similarity_w2v": sim_w2v
    })

similarities = pd.DataFrame(rows)

# %%
similarities.head()
# Out:
#      word1      word2  similarity_glove  similarity_w2v
# 0   vanish  disappear          0.881494        0.900423
# 1    quick      rapid          0.561225        0.497791
# 2  creator      maker          0.243845        0.260506
# 3   stupid       dumb          0.836065        0.817314
# 4   insane      crazy          0.591737        0.733904

# %%
# plots the distribution of similarity scores for each model
sims_w2v = similarities[['similarity_w2v']].rename(columns = {'similarity_w2v': 'similarity'})
sims_w2v['model'] = 'Word2vec'
sims_glove = similarities[['similarity_glove']].rename(columns = {'similarity_glove': 'similarity'})
sims_glove['model'] = 'GloVe'
to_plot = pd.concat([sims_w2v, sims_glove], ignore_index=True)
sns.displot(to_plot, x="similarity", hue="model", kind="kde")
plt.show()

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Extra quiz:
# Think about which model seems to perform better on these high-similarity examples and why based on your knowledge of how the embedding models have been trained.
#
# </div>

# %% [markdown]
# ----
#
# Glove performs better, because we can see has a negative skeweness that indicates higher similarity overall, which aligns better with the simlex evaluation. Maybe because since w2v learns by prediction, hence by which word fits more in a context, this gives less chance to learn more general structures that could be caught by a co existance matrix factorization

# %% [markdown]
# <a id="3"></a>
# ## 3. TASK C: Sentiment analysis of movie reviews
#
# For this part, we will be using only the GloVe pre-trained embeddings.
#
# **Data:** We will build a sentiment classification model using the IMDB review dataset.
#
# > - Download the dataset [here](https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews?phase=FinishSSORegistration). You may have to sign in / sign up on Kaggle.
# > - Save the .csv file in the same dir as this notebook.
#
# The IMDB dataset has 50K movie reviews for natural language processing or Text analytics. This is a dataset for binary sentiment classification containing substantially more data than previous benchmark datasets. We provide a set of 25,000 highly polar movie reviews for training and 25,000 for testing.
#
# The goal is to predict if a review is positive or negative using a classification (potentiall deep learning) algorithm.
#
# For more dataset information, please go through the following link,
# http://ai.stanford.edu/~amaas/data/sentiment/

# %% [markdown]
# ![IMDB-reviews-dataset-stats.png](attachment:IMDB-reviews-dataset-stats.png)

# %% [markdown]
# ### 3.1 Dataset exploration

# %%
#read dataset
movie_reviews = pd.read_csv('IMDB Dataset.csv')
movie_reviews.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print('Number of movie reviews: {}'.format(len(movie_reviews)))
classes = movie_reviews['sentiment'].unique()
print('Number of classes: {} with values: {}'.format(len(classes), classes))
# Out:
# Number of movie reviews: 50000
# Number of classes: 2 with values: <StringArray>
# ['positive', 'negative']
# Length: 2, dtype: str

# %%
# class distribution
positive = len(movie_reviews[movie_reviews['sentiment']=='positive'])
negative = len(movie_reviews[movie_reviews['sentiment']=='negative'])

print('# of positive samples: {}'.format(positive))
print('# of negative samples: {}'.format(negative))

sns.set_theme(rc={'figure.figsize':(5.7,5.27)})
sns.countplot(x=movie_reviews['sentiment'])
plt.show()
# Out:
# # of positive samples: 25000
# # of negative samples: 25000

# %% [markdown]
# ### 3.2 Data preprocessing
#
# To build our classifier, we will leverage the pre-trained word embeddings (GloVe). Going from word embeddings to sentence vectors, we will need to find a way to take into account the embeddings of all the words each review contains. We will apply 2 techniques to do so: average and max pooling.
#
# We will perform the following preprocessing steps:
# - Change the classes from str (negative, positive) to binary `(0, 1)`.
# - Get word embeddings and calculate the sentence vectors with both max and avg pooling.
# - Create a `pytorch.Dataset` instance of the IMDB data.

# %% [markdown]
# #### From class names to binary

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Change the classe names from str (negative, positive) to binary `(0, 1)` and add it as a new column to the exising dataframe.
#
# </div>

# %%
# classes to binary
movie_reviews['target'] = (movie_reviews['sentiment'] == 'positive').astype(int)

# %%
np.max(movie_reviews["target"])
# Out:
# np.int64(1)

# %% [markdown]
# #### From word embeddings to review embeddings

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** For each review in the dataset, calculate the review vector by pooling from the review's word embeddings. Implement both max and avg pooling.
# - 💻 **API:** You can use numpy functions to manipulate the arrays. For review tokenization you can use `gensim.utils.tokenize` function.
#
# </div>

# %%
from gensim.utils import tokenize
# apply embedding model to the words of the reviews and then perform pooling
def apply_embedding(review):
    tokens = simple_preprocess(review)
    vectors = []
    # print(review)
    for word in tokens:
        # print(word)
        if word in glove_vectors:
            vectors.append(glove_vectors[word])
    return np.array(vectors)

movie_reviews["review"] = movie_reviews["review"].apply(apply_embedding)

# %%
review_vectors_max = np.vstack(movie_reviews["review"].apply(lambda xx: np.max(xx, axis=0)))
review_vectors_avg = np.vstack(movie_reviews["review"].apply(lambda xx: np.mean(xx, axis=0)))

# %% [markdown]
# #### PyTorch Dataset class for the imported data

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Create a PyTorch Dataset class with the input data. Instantiate this class with the input data.
# - 💻 **API:** You can use `torch.utils.data.Dataset` class.
#
# </div>

# %%
class IMDBreviews(Dataset):
    def __init__(self, data, pooling):
        if pooling == "max":
            self.x = review_vectors_max
        if pooling == "mean":
            self.x = review_vectors_avg
        self.y = data["target"]
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        return self.x[index], self.y[index]

dataset = IMDBreviews(movie_reviews, "max")

# %%
# print tensors for sanity check
print('Total samples {} with sentence embedding size: {}'.format(dataset.x.shape[0], dataset.x.shape[1]))
# Out:
# Total samples 50000 with sentence embedding size: 100

# %% [markdown]
# #### Splitting dataset to train and test subsets

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Split the dataset into train and test sets (80-20% splits).
# - 💻 **API:** You can use `torch.utils.data.random_split` function.
#
# </div>

# %%
# split to train and test sets
train, test = torch.utils.data.random_split(dataset, lengths=[0.8, 0.2])

# %%
print('Train size: {}'.format(len(train)))
print('Test size: {}'.format(len(test)))
# Out:
# Train size: 40000
# Test size: 10000

# %% [markdown]
# ### 3.3 Train & evaluate a classifier on the movie reviews
#
# Once we have preprocessed the data, we will create the training and evaluation pipelines.

# %% [markdown]
# #### PyTorch Module class for model setup

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Create a PyTorch model class. The architecture of the model can be as simple as a Linear layer along with a sigmoid activation function, or a more complicated deep architecture. Play around with different settings and architectures.
# - 💻 **API:** You can use `torch.nn.Module` class.
#
# </div>

# %%
# create a pytorch nn.Module class for the simple logistic regression model
class SentimentAnalysisModel(nn.Module):

    def __init__(self, x):
        super(SentimentAnalysisModel, self).__init__()
        self.model = nn.Sequential( 
            nn.Linear(in_features=x.shape[1], out_features=1),
            nn.Sigmoid()
            )
        

    def forward(self, x):
        return self.model(x)

# %%
model = SentimentAnalysisModel(dataset.x)
model
# Out:
# SentimentAnalysisModel(
#   (model): Sequential(
#     (0): Linear(in_features=100, out_features=1, bias=True)
#     (1): Sigmoid()
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 101 trainable parameters

# %% [markdown]
# #### Pytorch Data loader class for dataset batching

# %%
# create data loader
BATCH_SIZE = 64
train_loader = DataLoader(train, batch_size=BATCH_SIZE, shuffle=True)
test_loader= DataLoader(test, batch_size=BATCH_SIZE)

# %% [markdown]
# #### Training the model

# %%
# Construct a loss function and an optimizer. The call to model.parameters()
# in the SGD constructor will contain the learnable parameters of the two
# nn.Linear modules which are members of the model.
from torch import optim
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=1e-1)

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Create the training loop: for each epoch, do the forward pass, compute the loss and do the backward propagation.
# - 💻 **API:** Check the official API for the [training process](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#train-the-network).
#
# </div>

# %%
# Training loop
model.train()
for epoch in range(10):
    epoch_loss = 0
    for i, data in enumerate(train_loader, 0):
        # get the inputs
        X, y = data
        
        optimizer.zero_grad()

        # Forward pass: Compute predicted y by passing x to the model
        y_hat = model(X)
        
        # Compute loss
        loss = criterion(y_hat.squeeze(), y.float())
        
        # Perform a backward pass, and update the weights.
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    print(f'Epoch {epoch + 1} | Loss: {(epoch_loss / len(train_loader)):.4f}')
# Out:
# Epoch 1 | Loss: 1.3529
# Epoch 2 | Loss: 1.1890
# Epoch 3 | Loss: 1.0159
# Epoch 4 | Loss: 0.9957
# Epoch 5 | Loss: 0.9447
# Epoch 6 | Loss: 0.9451
# Epoch 7 | Loss: 0.8996
# Epoch 8 | Loss: 0.9390
# Epoch 9 | Loss: 0.8968
# Epoch 10 | Loss: 0.8832

# %% [markdown]
# #### Inference on the test set

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Evaluate your model on the test set: for each batch of data, do the forward pass and compute the loss and the accuracy score.
# - 💻 **API:** Check the official API for the [testing process](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#test-the-network-on-the-test-data).
#
# </div>

# %%
batch_loss = 0
batch_acc = 0

model.eval()
for i, data in enumerate(test_loader, 0):
    # get the inputs
    X, y = data
    
    # run forward pass
    y_hat = model(X)
    
    # Compute loss
    test_loss = criterion(y_hat.squeeze(), y.float())
    
    # Compute accuracy
    acc = BinaryAccuracy()
    acc(preds=y_hat.squeeze(), target=y)
    
    batch_loss += test_loss.item()
    # retrieve the computed metric value rather than calling .item() on the metric object
    batch_acc += acc.compute().item()


test_loss = batch_loss / len(test_loader)
test_acc = batch_acc / len(test_loader)

print(f'Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Acc: 58.26%

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Extra quiz:
# Play around with different settings (e.g. learning rate, batch size, epochs) and different architectures. Additionally try different pooling methods. Think how your design choices affect model performance on both train and test sets.
#
# </div>

# %% [markdown]
# ### 🎉 Congrats! You finished your first exercise session!
#
# Awesome work!
